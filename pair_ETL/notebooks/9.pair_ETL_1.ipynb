# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import chi2_contingency, ttest_ind

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# lo primero que hacemos es cargar los dataframes que vamos a usar 

df_clientes = pd.read_csv("../data/clientes.csv", index_col = 0)
df_clientes.head()
# Out:
#     first_name last_name                         email  gender  \
# id
# 1        Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 2         Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 3   Michaeline   Paynton            mpaynton2@narod.ru  Female
# 4       Filmer    Eirwin            feirwin3@intel.com     NaN
# 5       Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                            City Country                   Address
# id
# 1             Palma De Mallorca   Spain  076 Rockefeller Crossing
# 2                          Lugo   Spain        0046 Utah Junction
# 3                           NaN   Spain          0 Corry Crossing
# 4                          Leon   Spain       5 American Ash Road
# 5   Hospitalet De Llobregat, L'   Spain         9289 Merry Circle

# %%
df_ventas = pd.read_csv("../data/ventas.csv", index_col = 0)
df_ventas.head()
# Out:
#            ID_Producto Fecha_Venta  Cantidad  Total
# ID_Cliente
# 723                 A1  2023-11-22         2  17.98
# 498                 C3  2023-11-21         1   5.49
# 121                 D4  2023-11-20         3  32.97
# 885                L12  2023-11-19         1   6.49
# 347                Q17  2023-11-18         2   7.98

# %%
df_productos = pd.read_csv("../data/productos.csv", sep=None, index_col = 0)
df_productos.head()
# Out:
#            Nombre_Producto          Categoría  Precio  Origen  \
# ID
# A1        Pizza Margherita  Platos Preparados    8.99  Italia
# B2  Risotto de Champiñones  Platos Preparados    6.75  Italia
# C3                Tiramisú            Postres    5.49  Italia
# D4               Panettone         Repostería   10.99  Italia
# E5             Orecchiette    Productos Secos    4.29  Italia
#
#                                           Descripción
# ID
# A1  Clásica pizza italiana con tomate,mozzarella f...
# B2  Risotto cremoso con champiñones frescos,una de...
# C3  Postre clásico italiano con capas de bizcocho ...
# D4  Pan dulce navideño italiano con frutas confita...
# E5  Pequeñas pastas con forma de orecchiette ideal...

# %%
df_clientes.shape
# Out:
# (1000, 7)

# %%
df_ventas.shape
# Out:
# (100, 4)

# %%
df_productos.shape
# Out:
# (33, 5)

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       973 non-null    object
#  3   gender      923 non-null    object
#  4   City        876 non-null    object
#  5   Country     846 non-null    object
#  6   Address     959 non-null    object
# dtypes: object(7)
# memory usage: 62.5+ KB

# %%
df_clientes['City'].isnull().sum()
# Out:
# 124

# %%
df_clientes['City'].unique()
# Out:
# array(['Palma De Mallorca', 'Lugo', nan, 'Leon',
#        "Hospitalet De Llobregat, L'", 'Lleida', 'Santander', 'Malaga',
#        'Valladolid', 'Murcia', 'Pamplona/Iruña', 'Barcelona', 'Palencia',
#        'Pontevedra', 'Girona', 'Fuenlabrada', 'Jaen', 'Almeria',
#        'Elx/Elche', 'Getafe', 'Sevilla', 'Coruña, A', 'Zaragoza',
#        'Palmas De Gran Canaria, Las', 'Cadiz', 'Tarragona',
#        'Santiago De Compostela', 'Donostia-San Sebastian', 'Cartagena',
#        'Madrid', 'Ceuta', 'Vigo', 'Valencia', 'Sabadell', 'Granada',
#        'Albacete', 'Teruel', 'Aviles',
#        'Castellon De La Plana/Castello De La Pla', 'Vitoria-Gasteiz',
#        'Zamora', 'Santa Cruz De Tenerife', 'Logroño', 'Torrevieja',
#        'Leganes', 'Gijon', 'Toledo', 'Badajoz', 'Dos Hermanas', 'Ourense',
#        'Ferrol', 'Salamanca', 'Sant Cugat Del Valles', 'Huesca',
#        'Alicante/Alacant', 'Telde'], dtype=object)

# %%
df_clientes['City'].value_counts(dropna=False, normalize=True)*100
# Out:
# City
# NaN                                         12.4
# Madrid                                       5.1
# Granada                                      4.2
# Palma De Mallorca                            4.1
# Malaga                                       3.6
# Vitoria-Gasteiz                              3.2
# Palmas De Gran Canaria, Las                  3.1
# Valencia                                     2.7
# Pamplona/Iruña                               2.7
# Pontevedra                                   2.4
# Cadiz                                        2.4
# Sevilla                                      2.4
# Lleida                                       2.3
# Zamora                                       2.2
# Valladolid                                   2.2
# Santander                                    2.2
# Donostia-San Sebastian                       2.1
# Logroño                                      2.0
# Albacete                                     2.0
# Leon                                         2.0
# Vigo                                         2.0
# Barcelona                                    1.8
# Badajoz                                      1.8
# Santiago De Compostela                       1.8
# Almeria                                      1.7
# Murcia                                       1.7
# Coruña, A                                    1.5
# Castellon De La Plana/Castello De La Pla     1.3
# Cartagena                                    1.2
# Jaen                                         1.2
# Sabadell                                     1.1
# Gijon                                        1.0
# Huesca                                       1.0
# Getafe                                       1.0
# Ceuta                                        1.0
# Fuenlabrada                                  0.9
# Leganes                                      0.8
# Girona                                       0.8
# Palencia                                     0.8
# Teruel                                       0.8
# Tarragona                                    0.8
# Ferrol                                       0.8
# Toledo                                       0.7
# Ourense                                      0.7
# Salamanca                                    0.7
# Dos Hermanas                                 0.7
# Lugo                                         0.7
# Elx/Elche                                    0.7
# Hospitalet De Llobregat, L'                  0.6
# Aviles                                       0.6
# Telde                                        0.6
# Santa Cruz De Tenerife                       0.5
# Zaragoza                                     0.5
# Torrevieja                                   0.3
# Sant Cugat Del Valles                        0.3
# Alicante/Alacant                             0.3
# Name: proportion, dtype: float64

# %%
df_clientes_loc = df_clientes.loc[pd.isna(df_clientes['City']), :]

# %%
df_clientes_loc
# Out:
#      first_name    last_name                      email  gender City Country  \
# id
# 3    Michaeline      Paynton         mpaynton2@narod.ru  Female  NaN   Spain
# 9         Tymon      Darragh          tdarragh8@free.fr    Male  NaN   Spain
# 11        Chase  Godilington   cgodilingtona@spiegel.de    Male  NaN     NaN
# 19         Sena     MacElane        smacelanei@youtu.be  Female  NaN   Spain
# 33       Adoree      Cutchey       acutcheyw@seesaa.net     NaN  NaN   Spain
# ..          ...          ...                        ...     ...  ...     ...
# 943     Maritsa        Doale         mdoaleq6@google.nl     NaN  NaN   Spain
# 962     Domenic        Adger          dadgerqp@time.com    Male  NaN   Spain
# 965      Marijn     St Clair  mstclairqs@technorati.com    Male  NaN   Spain
# 966        Didi       Hawtry   dhawtryqt@opensource.org  Female  NaN   Spain
# 987       Cecil        Hemms  chemmsre@reverbnation.com    Male  NaN   Spain
#
#                   Address
# id
# 3        0 Corry Crossing
# 9        41 Trailsway Way
# 11      13 Bluestem Court
# 19   8032 Claremont Trail
# 33      917 Marcy Parkway
# ..                    ...
# 943        7 Toban Center
# 962  327 Gateway Crossing
# 965          57 Jay Drive
# 966       901 Packers Way
# 987  1737 Commercial Lane
#
# [124 rows x 7 columns]

# %%
df_address_loc = df_clientes.loc[pd.isna(df_clientes['Address']), :]

# %%
df_address_loc
# Out:
#     first_name    last_name                           email      gender  \
# id
# 10        Igor      Dwelley            idwelley9@flickr.com        Male
# 35        Egon      Lafflin                elaffliny@a8.net        Male
# 73     Reinald       Platts             rplatts20@phpbb.com         NaN
# 74        Tate     Capehorn         tcapehorn21@comsenz.com        Male
# 82         Uta     Crasford                             NaN      Female
# 115     Carole     Biasetti             cbiasetti36@soup.io      Female
# 148    Carling        Pharo              cpharo43@youku.com        Male
# 157     Nancie    Radcliffe        nradcliffe4c@mozilla.org      Female
# 168      Storm      Musterd                             NaN      Female
# 176    Darrick       Lennox       dlennox4v@ycombinator.com        Male
# 190     Nancey      Fellnee             nfellnee59@cnet.com      Female
# 198  Corabelle        Goble              cgoble5h@fotki.com      Female
# 211      Bette       Fozard   bfozard5u@cargocollective.com      Female
# 243     Laurie      Harlowe        lharlowe6q@csmonitor.com         NaN
# 251      Brand      Haydney             bhaydney6y@usda.gov        Male
# 254   Sterling     Armstead          sarmstead71@unesco.org        Male
# 302     Berrie       Rubury   brubury8d@constantcontact.com  Polygender
# 375     Elisha      Pinwill           epinwillae@devhub.com      Female
# 381     Shelli      Cellier            scellierak@unblog.fr      Female
# 504    Desirae    Faircliff         dfaircliffdz@zimbio.com      Female
# 549    Vasilis     Vaughton              vvaughtonf8@goo.gl        Male
# 612   Germaine       Dragoe               gdragoegz@msn.com        Male
# 718      Corby  Le Marquand       clemarquandjx@youtube.com        Male
# 722    Ignacio      McComas         imccomask1@blogspot.com        Male
# 725       Nara    Fumagalli         nfumagallik4@scribd.com      Female
# 734       Abbe      Caunter  acaunterkd@cargocollective.com         NaN
# 739      Amory      Laherty              alahertyki@wix.com        Male
# 777       Noel  Mugglestone      nmugglestonelk@arizona.edu        Male
# 785       Olva      Cahalan            ocahalanls@ifeng.com      Female
# 788      Lissa        Regan           lreganlv@multiply.com      Female
# 806  Josephina          Doy         jdoymd@wunderground.com      Female
# 815    Ruperta       Meaker            rmeakermm@paypal.com      Female
# 848    Dorette         Muck     dmucknj@theglobeandmail.com      Female
# 849    Annabal    Blockwell      ablockwellnk@google.com.au    Bigender
# 856  Alejandro        Chese             achesenr@zimbio.com        Male
# 859      Luisa     Adelberg   ladelbergnu@elegantthemes.com      Female
# 911     Lorrin   O'Donoghue        lodonoghuepa@jiathis.com      Female
# 914     Garald      Billson          gbillsonpd@latimes.com        Male
# 947     Jamill       Lewson         jlewsonqa@cafepress.com        Male
# 974       Luke       Insley               linsleyr1@ftc.gov        Male
# 978   Cindelyn      Elbourn            celbournr5@hc360.com      Female
#
#                             City Country Address
# id
# 10                          Lugo   Spain     NaN
# 35                       Sevilla   Spain     NaN
# 73                        Malaga   Spain     NaN
# 74                     Barcelona   Spain     NaN
# 82                          Lugo   Spain     NaN
# 115                          NaN   Spain     NaN
# 148       Donostia-San Sebastian   Spain     NaN
# 157                          NaN   Spain     NaN
# 168                      Badajoz   Spain     NaN
# 176                          NaN     NaN     NaN
# 190                          NaN   Spain     NaN
# 198                    Santander   Spain     NaN
# 211                     Valencia     NaN     NaN
# 243                        Ceuta   Spain     NaN
# 251                       Lleida   Spain     NaN
# 254                       Aviles   Spain     NaN
# 302                      Leganes   Spain     NaN
# 375  Palmas De Gran Canaria, Las   Spain     NaN
# 381               Pamplona/Iruña   Spain     NaN
# 504                   Valladolid     NaN     NaN
# 549       Donostia-San Sebastian   Spain     NaN
# 612                          NaN     NaN     NaN
# 718                    Cartagena   Spain     NaN
# 722                      Almeria   Spain     NaN
# 725              Vitoria-Gasteiz   Spain     NaN
# 734                         Jaen     NaN     NaN
# 739                          NaN   Spain     NaN
# 777                       Zamora   Spain     NaN
# 785                   Pontevedra   Spain     NaN
# 788                        Cadiz   Spain     NaN
# 806                      Leganes   Spain     NaN
# 815                     Albacete   Spain     NaN
# 848                      Ourense   Spain     NaN
# 849                      Granada   Spain     NaN
# 856                     Palencia   Spain     NaN
# 859                       Murcia   Spain     NaN
# 911            Palma De Mallorca   Spain     NaN
# 914                          NaN     NaN     NaN
# 947  Hospitalet De Llobregat, L'   Spain     NaN
# 974               Pamplona/Iruña   Spain     NaN
# 978                        Ceuta   Spain     NaN

# %%
df_productos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, A1 to GG33
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre_Producto  33 non-null     object
#  1   Categoría        33 non-null     object
#  2   Precio           33 non-null     float64
#  3   Origen           33 non-null     object
#  4   Descripción      33 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 1.5+ KB

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 723 to 987
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_Producto  100 non-null    object
#  1   Fecha_Venta  100 non-null    object
#  2   Cantidad     100 non-null    int64
#  3   Total        100 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.9+ KB

# %%
df_ventas['Fecha_Venta'].unique()
# Out:
# array(['2023-11-22', '2023-11-21', '2023-11-20', '2023-11-19',
#        '2023-11-18', '2023-11-17', '2023-11-16', '2023-11-15',
#        '2023-11-14', '2023-11-13', '2023-11-08', '2023-11-07',
#        '2023-11-06', '2023-11-05', '2023-11-04', '2023-11-03',
#        '2023-11-02', '2023-11-01', '2023-10-31', '2023-10-30',
#        '2023-10-29', '2023-10-28', '2023-10-27', '2023-10-26',
#        '2023-10-25', '2023-10-24', '2023-10-23', '2023-10-22',
#        '2023-10-21', '2023-10-20', '2023-10-19', '2023-10-18',
#        '2023-10-17', '2023-10-16', '2023-10-15', '2023-10-14',
#        '2023-10-13', '2023-10-12', '2023-10-11', '2023-10-10',
#        '2023-10-09', '2023-10-08', '2023-10-07', '2023-10-06',
#        '2023-10-05', '2023-10-04', '2023-10-03', '2023-10-02',
#        '2023-10-01', '2023-09-30', '2023-09-29', '2023-09-28',
#        '2023-09-27', '2023-09-26', '2023-09-25', '2023-09-24',
#        '2023-09-23', '2023-09-22', '2023-09-21', '2023-09-20',
#        '2023-09-19', '2023-09-18', '2023-09-17', '2023-09-16',
#        '2023-09-15', '2023-09-14', '2023-09-13', '2023-09-12',
#        '2023-09-11', '2023-09-10', '2023-09-09', '2023-09-08',
#        '2023-09-07', '2023-09-06', '2023-09-05', '2023-09-04',
#        '2023-09-03', '2023-09-02', '2023-09-01', '2023-08-31'],
#       dtype=object)

# %%
df_ventas['Fecha_Venta'] = pd.to_datetime(df_ventas['Fecha_Venta'])
# nuevamente usamos dtypes sobre el dataframe para corroborar de que tipo es cada columna.
df_ventas.dtypes
# Out:
# ID_Producto            object
# Fecha_Venta    datetime64[ns]
# Cantidad                int64
# Total                 float64
# dtype: object

# %%
df_clientes.duplicated().sum()
# Out:
# 0

# %%
df_ventas.duplicated().sum()
# Out:
# 0

# %%
df_productos.duplicated().sum()
# Out:
# 0

# %%
df_clientes['Country'].unique()
# Out:
# array(['Spain', nan], dtype=object)

# %%
df_clientes['Country'] = df_clientes['Country'].fillna('Spain')

# %%
df_clientes['Country'].unique()
# Out:
# array(['Spain'], dtype=object)
